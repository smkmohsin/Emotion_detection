# %% [markdown]
# <a href="https://colab.research.google.com/github/smkmohsin/Emotion_detection/blob/main/emotion_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
from deepface import DeepFace

# %%
img = cv2.imread('happyboy.jpg')

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.12it/s]

# %%
prediction
# Out:
# {'emotion': {'angry': 1.2167652952907448e-10,
#   'disgust': 3.501115480972379e-12,
#   'fear': 2.4253210995084373e-06,
#   'happy': 99.99988079071045,
#   'sad': 9.627660890743073e-08,
#   'surprise': 3.477477637445214e-11,
#   'neutral': 0.00011880239298989181},
#  'dominant_emotion': 'happy',
#  'region': {'x': 49, 'y': 32, 'w': 104, 'h': 104},
#  'age': 21,
#  'gender': 'Man',
#  'race': {'asian': 1.8333079293370247,
#   'indian': 1.1038504540920258,
#   'black': 0.17416415503248572,
#   'white': 55.73941469192505,
#   'middle eastern': 14.305251836776733,
#   'latino hispanic': 26.84400975704193},
#  'dominant_race': 'white'}

# %%
prediction['dominant_emotion']
# Out:
# 'happy'

# %% [markdown]
# # We try to draw rectangle around face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray, 1.1,4)


for x, y, w, h in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
    
    
# Use putText() method for
# inseting text on video
cv2.putText(img,
           prediction['dominant_emotion'],
           (0, 50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
